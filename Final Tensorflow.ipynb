# %% [markdown]
# '''Final project
#
# Student name: Oanh Doan Thi Hoang
#                 Yusuke
# '''

# %%
import tensorflow as tf
import numpy as np
import time
import os
import matplotlib.pyplot as plt
from itertools import chain
from sklearn.preprocessing import OneHotEncoder

import numpy as np
import pandas as pd
import tensorflow as tf
import keras.preprocessing.image
import sklearn.preprocessing
import sklearn.model_selection
import sklearn.metrics
import sklearn.linear_model
import sklearn.naive_bayes
import sklearn.tree
import sklearn.ensemble

import datetime  
import cv2 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm  
# %matplotlib inline
# Out:
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\utils\fixes.py:313: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   _nan_object_mask = _nan_object_array != _nan_object_array
# Using TensorFlow backend.

# %%
X=x_images = np.load('C:/Users/missd/tensorflow/Final Project/Cancer image/X.npy') 
Y=y_images = np.load('C:/Users/missd/tensorflow/Final Project/Cancer image/Y.npy')

# %%
perm_array = np.arange(len(x_images))
np.random.shuffle(perm_array)
x_images = x_images[perm_array]
y_images = y_images[perm_array]

print('x_images.shape (images,Width, Height, Channels) =', x_images.shape)
print('x_images.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(x_images.min(),
                        x_images.mean(), x_images.std(), x_images.max()))
print('')
print('y_images.shape =', y_images.shape)
print('y_images.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(y_images.min(),
                        y_images.mean(), y_images.std(), y_images.max()))
print('')
print('Number of IDC(-) Images:', np.sum(Y==0))
print('Number of IDC(+) Images:', np.sum(Y==1))
print('Percentage of positive images:', (100*np.mean(Y)))
# Out:
# x_images.shape (images,Width, Height, Channels) = (5547, 50, 50, 3)
# x_images.min/mean/std/max = 2.00/185.03/47.25/255.00
#
# y_images.shape = (5547,)
# y_images.min/mean/std/max = 0.00/0.50/0.50/1.00
#
# Number of IDC(-) Images: 2759
# Number of IDC(+) Images: 2788
# Percentage of positive images: 50.2614025599

# %%
## plot some images  

imgs_0 = X[y_images == 0] # 0 = no cancer
imgs_1 = Y[y_images == 1] # 1 = cancer

plt.figure(figsize=(20,20))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.title('IDC = %d'%y_images[i])
    plt.imshow(x_images[i])

# %%
plt.figure(figsize=(14,3))

for i in range(2):
    n_img = np.random.randint(len(x_images))
    plt.subplot(1,4,1+2*i)
    plt.title('IDC = %d'%Y[n_img])
    plt.imshow(X[n_img])
    plt.subplot(1,4,2+2*i)
    plt.title('IDC = %d'%Y[n_img])
    plt.ylabel('Count')
    plt.xlabel('Pixel Intensity')
    plt.hist(X[n_img,:,:,0].flatten(), bins=30, lw = 0,color='r', alpha=0.5);
    plt.hist(X[n_img,:,:,1].flatten(), bins=30, lw = 0, color='g', alpha=0.5);
    plt.hist(X[n_img,:,:,2].flatten(), bins=30, lw = 0, color='b', alpha=0.5);

print('Red channel: min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(x_images[:,:,:,0].min(),
    x_images[:,:,:,0].mean(), x_images[:,:,:,0].std(), x_images[:,:,:,0].max()))
print('Green channel: min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(x_images[:,:,:,1].min(),
    x_images[:,:,:,1].mean(), x_images[:,:,:,1].std(), x_images[:,:,:,1].max()))
print('Blue channel: min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(x_images[:,:,:,2].min(),
    x_images[:,:,:,2].mean(), x_images[:,:,:,2].std(), x_images[:,:,:,2].max()))
# Out:
# Red channel: min/mean/std/max = 4.00/205.79/36.29/255.00
# Green channel: min/mean/std/max = 2.00/161.87/53.94/255.00
# Blue channel: min/mean/std/max = 5.00/187.44/38.69/255.00

# %% [markdown]
# ## Manipulate data

# %%
## normalize data

# convert one-hot encodings into labels
def one_hot_to_dense(labels_one_hot):
    return np.argmax(labels_one_hot,1)

# convert class labels from scalars to one-hot vectors e.g. 1 => [0 1], 0 => [1 0]
def dense_to_one_hot(labels_dense, num_classes):
    num_labels = labels_dense.shape[0]
    index_offset = np.arange(num_labels) * num_classes
    labels_one_hot = np.zeros((num_labels, num_classes))
    labels_one_hot.flat[index_offset + labels_dense.ravel()] = 1
    return labels_one_hot
# function to normalize data
def normalize_data(data): 
    # scale features using statistics that are robust to outliers
    #rs = sklearn.preprocessing.RobustScaler()
    #rs.fit(data)
    #data = rs.transform(data)
    #data = (data-data.mean())/(data.std()) # standardisation
    data = data / data.max() # convert from [0:255] to [0.:1.]
    #data = ((data / 255.)-0.5)*2. # convert from [0:255] to [-1.:+1.]
    return data

# training and validation data
x_train_valid = normalize_data(x_images)

# use one-hot encoding for labels 0,1
y_train_valid = dense_to_one_hot(y_images, 2).astype(np.uint8)

# dictionaries for saving results
y_valid_pred = {}
y_train_pred = {}
y_test_pred = {}
train_loss, valid_loss = {}, {}
train_acc, valid_acc = {}, {}
cnf_valid_matrix = {}

print('x_train_valid.shape =', x_train_valid.shape)
print('x_train_valid.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(x_train_valid.min(),
                        x_train_valid.mean(), x_train_valid.std(), x_train_valid.max()))
print('')
print('y_train_valid.shape =', y_train_valid.shape)
print('y_train_valid.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(y_train_valid.min(),
                        y_train_valid.mean(), y_train_valid.std(), y_train_valid.max()))
# Out:
# x_train_valid.shape = (5547, 50, 50, 3)
# x_train_valid.min/mean/std/max = 0.01/0.73/0.19/1.00
#
# y_train_valid.shape = (5547, 2)
# y_train_valid.min/mean/std/max = 0.00/0.50/0.50/1.00

# %%
## augment data

# generate new images via rotations, translations, zoom using keras
def generate_images(imgs):
    
    # rotations, translations, zoom
    image_generator = keras.preprocessing.image.ImageDataGenerator(
        rotation_range = 10, width_shift_range = 0.1 , height_shift_range = 0.1,
        zoom_range = 0.1)

    # get transformed images
    imgs = image_generator.flow(imgs.copy(), np.zeros(len(imgs)),
                                batch_size=len(imgs), shuffle = False).next()    
    return imgs[0]

# check image generation
fig,axs = plt.subplots(5,6, figsize=(20,15))
for i in range(5):
    n = np.random.randint(0,x_images.shape[0]-2)
    axs[i,0].imshow(x_images[n])
    axs[i,1].imshow(generate_images(x_images[n:n+1])[0].astype('uint8'))
    axs[i,2].imshow(generate_images(x_images[n:n+1])[0].astype('uint8'))
    axs[i,3].imshow(generate_images(x_images[n:n+1])[0].astype('uint8'))
    axs[i,4].imshow(generate_images(x_images[n:n+1])[0].astype('uint8'))
    axs[i,5].imshow(generate_images(x_images[n:n+1])[0].astype('uint8'))

# %% [markdown]
# ##Try out sklearn base models

# %%
## First try out some basic sklearn models

# computet the accuracy of label predictions
def accuracy_from_dense_labels(y_target, y_pred):
    y_target = y_target.reshape(-1,)
    y_pred = y_pred.reshape(-1,)
    return np.mean(y_target == y_pred)

logreg = sklearn.linear_model.LogisticRegression(verbose=0, solver='lbfgs',
                                                 multi_class = 'multinomial')
decision_tree = sklearn.tree.DecisionTreeClassifier()
extra_trees = sklearn.ensemble.ExtraTreesClassifier(verbose=0, max_depth=4)
gradient_boost = sklearn.ensemble.GradientBoostingClassifier(verbose=0)
random_forest = sklearn.ensemble.RandomForestClassifier(verbose=0, max_depth=4, n_estimators=10)
gaussianNB = sklearn.naive_bayes.GaussianNB()


# store models in dictionary
base_models = {'logreg': logreg, 'extra_trees': extra_trees,
               'gradient_boost': gradient_boost, 'random_forest': random_forest, 
               'decision_tree': decision_tree, 'gaussianNB': gaussianNB}

# choose models for out-of-folds predictions
#take_models = ['logreg','random_forest','extra_trees','gaussianNB']
take_models = ['logreg', 'random_forest', 'extra_trees', 'gaussianNB']

for mn in take_models:
    train_acc[mn] = []
    valid_acc[mn] = []
    cnf_valid_matrix[mn] = []

# start timer
start = datetime.datetime.now();
print(datetime.datetime.now().strftime('%d-%m-%Y %H:%M:%S'),': start training')
       
# cross validations
cv_num = 10 # cross validations default = 20 => 5% validation set
kfold = sklearn.model_selection.KFold(cv_num, shuffle=True) #, random_state=123)

for i,(train_index, valid_index) in enumerate(kfold.split(x_train_valid)):

    # start timer
    start = datetime.datetime.now();

    # train and validation data of original images
    x_train = x_train_valid[train_index].reshape(-1,7500)
    y_train = y_train_valid[train_index]
    x_valid = x_train_valid[valid_index].reshape(-1,7500)
    y_valid = y_train_valid[valid_index]

    for mn in take_models:

        # create cloned model from base models
        model = sklearn.base.clone(base_models[mn])
        model.fit(x_train, one_hot_to_dense(y_train))

        # predictions
        y_train_pred[mn] = model.predict_proba(x_train)
        y_valid_pred[mn] = model.predict_proba(x_valid)
        
        # accuracies
        train_acc[mn].append(accuracy_from_dense_labels(one_hot_to_dense(y_train_pred[mn]),
                                                        one_hot_to_dense(y_train)))
        valid_acc[mn].append(accuracy_from_dense_labels(one_hot_to_dense(y_valid_pred[mn]),
                                                        one_hot_to_dense(y_valid)))
        
        # normalized confusion matrix
        cnf_valid_matrix_tmp = sklearn.metrics.confusion_matrix(
            y_pred = one_hot_to_dense(y_valid_pred[mn]), 
            y_true = one_hot_to_dense(y_valid)).astype(np.float32)
        cnf_valid_matrix_tmp[0,:] = cnf_valid_matrix_tmp[0,:]/cnf_valid_matrix_tmp[0,:].sum()
        cnf_valid_matrix_tmp[1,:] = cnf_valid_matrix_tmp[1,:]/cnf_valid_matrix_tmp[1,:].sum()
        cnf_valid_matrix[mn].append(cnf_valid_matrix_tmp)

        print(i,': '+mn+' train/valid accuracy = %.3f/%.3f'%(train_acc[mn][-1], 
                                                             valid_acc[mn][-1]))

print('running time for training: ', datetime.datetime.now() - start)
print('')
for mn in train_acc.keys():
    print(mn + ' : averaged train/valid accuracy = %.3f/%.3f'%(np.mean(train_acc[mn]),
                                                              np.mean(valid_acc[mn])))
# Out:
# 28-03-2019 14:51:11 : start training
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 0 : logreg train/valid accuracy = 0.846/0.677
# 0 : random_forest train/valid accuracy = 0.789/0.760
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0 : extra_trees train/valid accuracy = 0.768/0.764
# 0 : gaussianNB train/valid accuracy = 0.713/0.739
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 1 : logreg train/valid accuracy = 0.919/0.676
# 1 : random_forest train/valid accuracy = 0.785/0.759
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 1 : extra_trees train/valid accuracy = 0.771/0.744
# 1 : gaussianNB train/valid accuracy = 0.714/0.719
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 2 : logreg train/valid accuracy = 0.844/0.697
# 2 : random_forest train/valid accuracy = 0.787/0.782
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 2 : extra_trees train/valid accuracy = 0.771/0.769
# 2 : gaussianNB train/valid accuracy = 0.715/0.721
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 3 : logreg train/valid accuracy = 0.885/0.663
# 3 : random_forest train/valid accuracy = 0.787/0.737
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 3 : extra_trees train/valid accuracy = 0.773/0.751
# 3 : gaussianNB train/valid accuracy = 0.717/0.703
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 4 : logreg train/valid accuracy = 0.849/0.636
# 4 : random_forest train/valid accuracy = 0.790/0.746
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 4 : extra_trees train/valid accuracy = 0.771/0.728
# 4 : gaussianNB train/valid accuracy = 0.716/0.706
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 5 : logreg train/valid accuracy = 0.844/0.703
# 5 : random_forest train/valid accuracy = 0.782/0.753
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 5 : extra_trees train/valid accuracy = 0.772/0.751
# 5 : gaussianNB train/valid accuracy = 0.716/0.705
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 6 : logreg train/valid accuracy = 0.843/0.685
# 6 : random_forest train/valid accuracy = 0.788/0.762
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 6 : extra_trees train/valid accuracy = 0.768/0.759
# 6 : gaussianNB train/valid accuracy = 0.715/0.721
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 7 : logreg train/valid accuracy = 0.852/0.699
# 7 : random_forest train/valid accuracy = 0.783/0.755
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 7 : extra_trees train/valid accuracy = 0.772/0.753
# 7 : gaussianNB train/valid accuracy = 0.716/0.711
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 8 : logreg train/valid accuracy = 0.842/0.695
# 8 : random_forest train/valid accuracy = 0.786/0.776
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 8 : extra_trees train/valid accuracy = 0.769/0.762
# 8 : gaussianNB train/valid accuracy = 0.716/0.704
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 9 : logreg train/valid accuracy = 0.870/0.686
# 9 : random_forest train/valid accuracy = 0.785/0.776
# C:\Users\missd\.conda\envs\tf-cpu\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 9 : extra_trees train/valid accuracy = 0.771/0.767
# 9 : gaussianNB train/valid accuracy = 0.714/0.722
# running time for training:  0:00:12.044152
#
# gaussianNB : averaged train/valid accuracy = 0.715/0.715
# random_forest : averaged train/valid accuracy = 0.786/0.761
# extra_trees : averaged train/valid accuracy = 0.771/0.755
# logreg : averaged train/valid accuracy = 0.859/0.682

# %%
## show confusion matrix of one model

# choose model
mn = 'logreg'

# plot
labels_array = ['IDC = 0', 'IDC = 1']
fig, ax = plt.subplots(1,figsize=(5,5))
ax = sns.heatmap(cnf_valid_matrix[mn][0], ax=ax, cmap=plt.cm.Greens, annot=True)
ax.set_xticklabels(labels_array)
ax.set_yticklabels(labels_array)
plt.title('Confusion matrix of validation set')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show();

# %%
## compare base models

# boxplot algorithm comparison
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(1,2,1)
plt.title('Train accuracy')
plt.boxplot([train_acc[mn] for mn in train_acc.keys()])
ax.set_xticklabels([mn for mn in train_acc.keys()])
ax.set_ylabel('Accuracy');

ax = fig.add_subplot(1,2,2)
plt.title('Valid accuracy')
plt.boxplot([valid_acc[mn] for mn in train_acc.keys()])
ax.set_xticklabels([mn for mn in train_acc.keys()])
ax.set_ylabel('Accuracy');

for mn in train_acc.keys():
    print(mn + ' averaged train/valid accuracy = %.3f/%.3f'%(np.mean(train_acc[mn]),
                                                             np.mean(valid_acc[mn])))
# Out:
# gaussianNB averaged train/valid accuracy = 0.715/0.715
# random_forest averaged train/valid accuracy = 0.786/0.761
# extra_trees averaged train/valid accuracy = 0.771/0.755
# logreg averaged train/valid accuracy = 0.859/0.682

# %%
## build the neural network class

class nn_class:
# class that implements the neural network

    # constructor
    def __init__(self, nn_name = 'tmp', log_step = 0.1, keep_prob = 0.33, mb_size = 50,
                 width = 50, height = 50, n_channel = 3, n_output = 2):

        # tunable hyperparameters for nn architecture
        self.s_f_conv1 = 3 # filter size of first convolution layer (default = 3)
        self.n_f_conv1 = 36 # number of features of first convolution layer (default = 36)
        self.s_f_conv2 = 3 # filter size of second convolution layer (default = 3)
        self.n_f_conv2 = 36 # number of features of second convolution layer (default = 36)
        self.s_f_conv3 = 3 # filter size of third convolution layer (default = 3)
        self.n_f_conv3 = 36 # number of features of third convolution layer (default = 36)
        self.n_n_fc1 = 576 # number of neurons of first fully connected layer (default = 576)
        self.n_channel = n_channel
        self.width = width
        self.height = height
        self.n_output = n_output
        
        # tunable hyperparameters for training
        self.mb_size = mb_size # mini batch size
        self.keep_prob = keep_prob # keeping probability with dropout regularization 
        self.learn_rate_array = [10*1e-4, 7.5*1e-4, 5*1e-4, 2.5*1e-4, 1*1e-4, 1*1e-4,
                                 1*1e-4, 0.75*1e-4, 0.5*1e-4, 0.25*1e-4, 0.1*1e-4, 
                                 0.1*1e-4, 0.075*1e-4,0.050*1e-4, 0.025*1e-4, 0.01*1e-4, 
                                 0.0075*1e-4, 0.0050*1e-4,0.0025*1e-4,0.001*1e-4]
        self.learn_rate_step_size = 3 # in terms of epochs
        
        # helper variables
        self.learn_rate = self.learn_rate_array[0]
        self.learn_rate_pos = 0 # current position pointing to current learning rate
        self.index_in_epoch = 0 
        self.current_epoch = 0
        self.log_step = log_step # log results in terms of epochs
        self.n_log_step = 0 # counting current number of mini batches trained on
        self.use_tb_summary = False # True = use tensorboard visualization
        self.use_tf_saver = False # True = use saver to save the model
        self.nn_name = nn_name # name of the neural network
        self.perm_array = np.array([]) # permutation array
        
    # function to get the next mini batch
    def next_mini_batch(self):

        start = self.index_in_epoch
        self.index_in_epoch += self.mb_size
        self.current_epoch += self.mb_size/len(self.x_train)  
        
        # adapt length of permutation array
        if not len(self.perm_array) == len(self.x_train):
            self.perm_array = np.arange(len(self.x_train))
        
        # shuffle once at the start of epoch
        if start == 0:
            np.random.shuffle(self.perm_array)

        # at the end of the epoch
        if self.index_in_epoch > self.x_train.shape[0]:
            np.random.shuffle(self.perm_array) # shuffle data
            start = 0 # start next epoch
            self.index_in_epoch = self.mb_size # set index to mini batch size
            
            if self.train_on_augmented_data:
                # use augmented data for the next epoch
                self.x_train_aug = normalize_data(self.generate_images(self.x_train))
                self.y_train_aug = self.y_train
                
        end = self.index_in_epoch
        
        if self.train_on_augmented_data:
            # use augmented data
            x_tr = self.x_train_aug[self.perm_array[start:end]]
            y_tr = self.y_train_aug[self.perm_array[start:end]]
        else:
            # use original data
            x_tr = self.x_train[self.perm_array[start:end]]
            y_tr = self.y_train[self.perm_array[start:end]]
        
        return x_tr, y_tr
               
    # generate new images via rotations, translations, zoom using keras
    def generate_images(self, imgs):
    
        print('generate new set of images')
        
        # rotations, translations, zoom
        image_generator = keras.preprocessing.image.ImageDataGenerator(
            rotation_range = 10, width_shift_range = 0.1 , height_shift_range = 0.1,
            zoom_range = 0.1)

        # get transformed images
        imgs = image_generator.flow(imgs.copy(), np.zeros(len(imgs)),
                                    batch_size=len(imgs), shuffle = False).next()    

        return imgs[0]

    # weight initialization
    def weight_variable(self, shape, name = None):
        initial = tf.truncated_normal(shape, stddev=0.1)
        return tf.Variable(initial, name = name)

    # bias initialization
    def bias_variable(self, shape, name = None):
        initial = tf.constant(0.1, shape=shape) #  positive bias
        return tf.Variable(initial, name = name)

    # 2D convolution
    def conv2d(self, x, W, name = None):
        return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME', name = name)

    # max pooling
    def max_pool_2x2(self, x, name = None):
        return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1],
                              padding='SAME', name = name)

    # attach summaries to a tensor for TensorBoard visualization
    def summary_variable(self, var, var_name):
        with tf.name_scope(var_name):
            mean = tf.reduce_mean(var)
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
            tf.summary.scalar('mean', mean)
            tf.summary.scalar('stddev', stddev)
            tf.summary.scalar('max', tf.reduce_max(var))
            tf.summary.scalar('min', tf.reduce_min(var))
            tf.summary.histogram('histogram', var)
    
    # function to create the graph
    def create_graph(self):

        # reset default graph
        tf.reset_default_graph()

        # variables for input and output 
        self.x_data_tf = tf.placeholder(dtype=tf.float32, shape=[None,self.height,
                                        self.width,self.n_channel], name='x_data_tf')
        self.y_data_tf = tf.placeholder(dtype=tf.float32, shape=[None, self.n_output],
                                        name='y_data_tf')

        # 1.layer: convolution + max pooling
        self.W_conv1_tf = self.weight_variable([self.s_f_conv1, self.s_f_conv1, self.n_channel,
                                                self.n_f_conv1], name='W_conv1_tf') # (3,3,3,36)
        self.b_conv1_tf = self.bias_variable([self.n_f_conv1], name = 'b_conv1_tf') # (36)
        self.h_conv1_tf = tf.nn.relu(self.conv2d(self.x_data_tf, self.W_conv1_tf) 
                                     + self.b_conv1_tf, name = 'h_conv1_tf') # (.,50,50,36)
        self.h_pool1_tf = self.max_pool_2x2(self.h_conv1_tf, 
                                            name = 'h_pool1_tf') # (.,25,25,36)
        
        # 2.layer: convolution + max pooling
        self.W_conv2_tf = self.weight_variable([self.s_f_conv2, self.s_f_conv2, 
                                self.n_f_conv1, self.n_f_conv2], name = 'W_conv2_tf')
        self.b_conv2_tf = self.bias_variable([self.n_f_conv2], name = 'b_conv2_tf')
        self.h_conv2_tf = tf.nn.relu(self.conv2d(self.h_pool1_tf, 
                        self.W_conv2_tf) + self.b_conv2_tf, name ='h_conv2_tf') #(.,25,25,36)
        self.h_pool2_tf = self.max_pool_2x2(self.h_conv2_tf, name = 'h_pool2_tf') #(.,13,13,36)

        # 3.layer: convolution + max pooling
        self.W_conv3_tf = self.weight_variable([self.s_f_conv3, self.s_f_conv3, 
                        self.n_f_conv2, self.n_f_conv3], name = 'W_conv3_tf')
        self.b_conv3_tf = self.bias_variable([self.n_f_conv3], name = 'b_conv3_tf')
        self.h_conv3_tf = tf.nn.relu(self.conv2d(self.h_pool2_tf, self.W_conv3_tf) + 
                                     self.b_conv3_tf, name ='h_conv3_tf') #(.,13,13,36)
        self.h_pool3_tf = self.max_pool_2x2(self.h_conv3_tf, name='h_pool3_tf') # (.,7,7,36)
        
        # 4.layer: fully connected
        self.W_fc1_tf = self.weight_variable([7*7*self.n_f_conv3, self.n_n_fc1], 
                                             name='W_fc1_tf') # (7*7*36, 1024)
        self.b_fc1_tf = self.bias_variable([self.n_n_fc1], name = 'b_fc1_tf') # (1024)
        self.h_pool3_flat_tf = tf.reshape(self.h_pool3_tf, [-1,7*7*self.n_f_conv3], 
                                          name = 'h_pool3_flat_tf') # (.,1024)
        self.h_fc1_tf = tf.nn.relu(tf.matmul(self.h_pool3_flat_tf, 
                           self.W_fc1_tf) + self.b_fc1_tf, name = 'h_fc1_tf') # (.,1024)
      
        # add dropout
        self.keep_prob_tf = tf.placeholder(dtype=tf.float32, name = 'keep_prob_tf')
        self.h_fc1_drop_tf = tf.nn.dropout(self.h_fc1_tf, self.keep_prob_tf, 
                                           name = 'h_fc1_drop_tf')

        # 5.layer: fully connected
        self.W_fc2_tf = self.weight_variable([self.n_n_fc1, self.n_output],
                                             name='W_fc2_tf') # (1024,1)
        self.b_fc2_tf = self.bias_variable([self.n_output], name='b_fc2_tf') # (1024)
        self.z_pred_tf = tf.add(tf.matmul(self.h_fc1_drop_tf, self.W_fc2_tf), 
                                self.b_fc2_tf, name = 'z_pred_tf')# => (.,1)

        # cost function
        self.cross_entropy_tf = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
            labels=self.y_data_tf, logits=self.z_pred_tf), name = 'cross_entropy_tf')
     
        # optimisation function
        self.learn_rate_tf = tf.placeholder(dtype=tf.float32, name="learn_rate_tf")
        self.train_step_tf = tf.train.AdamOptimizer(self.learn_rate_tf).minimize(
            self.cross_entropy_tf, name = 'train_step_tf')

        # predicted probabilities in one-hot encoding
        self.y_pred_proba_tf = tf.nn.softmax(self.z_pred_tf, name='y_pred_proba_tf') 
        
        # tensor of correct predictions
        self.y_pred_correct_tf = tf.equal(tf.argmax(self.y_pred_proba_tf, 1),
                                          tf.argmax(self.y_data_tf, 1),
                                          name = 'y_pred_correct_tf')  
        
        # accuracy 
        self.accuracy_tf = tf.reduce_mean(tf.cast(self.y_pred_correct_tf, dtype=tf.float32),
                                         name = 'accuracy_tf')

        # tensors to save intermediate accuracies and losses during training
        self.train_loss_tf = tf.Variable(np.array([]), dtype=tf.float32, 
                                         name='train_loss_tf', validate_shape = False)
        self.valid_loss_tf = tf.Variable(np.array([]), dtype=tf.float32, 
                                         name='valid_loss_tf', validate_shape = False)
        self.train_acc_tf = tf.Variable(np.array([]), dtype=tf.float32, 
                                        name='train_acc_tf', validate_shape = False)
        self.valid_acc_tf = tf.Variable(np.array([]), dtype=tf.float32, 
                                        name='valid_acc_tf', validate_shape = False)
     
        # number of weights and biases
        num_weights = (self.s_f_conv1**2*self.n_f_conv1*self.n_channel
                       + self.s_f_conv2**2*self.n_f_conv1*self.n_f_conv2 
                       + self.s_f_conv3**2*self.n_f_conv2*self.n_f_conv3 
                       + 4*4*self.n_f_conv3*self.n_n_fc1 + self.n_n_fc1*self.n_output)
        num_biases = self.n_f_conv1 + self.n_f_conv2 + self.n_f_conv3 + self.n_n_fc1
        print('num_weights =', num_weights)
        print('num_biases =', num_biases)
        
        return None  
    
    def attach_summary(self, sess):
        
        # create summary tensors for tensorboard
        self.use_tb_summary = True
        self.summary_variable(self.W_conv1_tf, 'W_conv1_tf')
        self.summary_variable(self.b_conv1_tf, 'b_conv1_tf')
        self.summary_variable(self.W_conv2_tf, 'W_conv2_tf')
        self.summary_variable(self.b_conv2_tf, 'b_conv2_tf')
        self.summary_variable(self.W_conv3_tf, 'W_conv3_tf')
        self.summary_variable(self.b_conv3_tf, 'b_conv3_tf')
        self.summary_variable(self.W_fc1_tf, 'W_fc1_tf')
        self.summary_variable(self.b_fc1_tf, 'b_fc1_tf')
        self.summary_variable(self.W_fc2_tf, 'W_fc2_tf')
        self.summary_variable(self.b_fc2_tf, 'b_fc2_tf')
        tf.summary.scalar('cross_entropy_tf', self.cross_entropy_tf)
        tf.summary.scalar('accuracy_tf', self.accuracy_tf)

        # merge all summaries for tensorboard
        self.merged = tf.summary.merge_all()

        # initialize summary writer 
        timestamp = datetime.datetime.now().strftime('%d-%m-%Y_%H-%M-%S')
        filepath = os.path.join(os.getcwd(), 'logs', (self.nn_name+'_'+timestamp))
        self.train_writer = tf.summary.FileWriter(os.path.join(filepath,'train'), sess.graph)
        self.valid_writer = tf.summary.FileWriter(os.path.join(filepath,'valid'), sess.graph)

    def attach_saver(self):
        # initialize tensorflow saver
        self.use_tf_saver = True
        self.saver_tf = tf.train.Saver()

    # function to train the graph
    def train_graph(self, sess, x_train, y_train, x_valid, y_valid, n_epoch = 1, 
                    train_on_augmented_data = False):

        # train on original or augmented data
        self.train_on_augmented_data = train_on_augmented_data
        
        # training and validation data
        self.x_train = x_train
        self.y_train = y_train
        self.x_valid = x_valid
        self.y_valid = y_valid
        
        # use augmented data
        if self.train_on_augmented_data:
            print('generate new set of images')
            self.x_train_aug = normalize_data(self.generate_images(self.x_train))
            self.y_train_aug = self.y_train
        
        # parameters
        mb_per_epoch = self.x_train.shape[0]/self.mb_size
        train_loss, train_acc, valid_loss, valid_acc = [],[],[],[]
        
        # start timer
        start = datetime.datetime.now();
        print(datetime.datetime.now().strftime('%d-%m-%Y %H:%M:%S'),': start training')
        print('learnrate =',self.learn_rate,', n_epoch =', n_epoch,
              ', mb_size =', self.mb_size, ', nn_name =', self.nn_name)
        # looping over mini batches
        for i in range(int(n_epoch*mb_per_epoch)+1):

            # adapt learn_rate
            if not self.learn_rate_pos == int(self.current_epoch // self.learn_rate_step_size):
                self.learn_rate_pos = int(self.current_epoch // self.learn_rate_step_size)
                self.learn_rate = self.learn_rate_array[self.learn_rate_pos]
                print(datetime.datetime.now()-start,': set learn rate to %.6f'%self.learn_rate)
            
            # get new batch
            x_batch, y_batch = self.next_mini_batch() 

            # run the graph
            sess.run(self.train_step_tf, feed_dict={self.x_data_tf: x_batch, 
                                                    self.y_data_tf: y_batch, 
                                                    self.keep_prob_tf: self.keep_prob, 
                                                    self.learn_rate_tf: self.learn_rate})
            # store losses and accuracies
            if i%int(self.log_step*mb_per_epoch) == 0 or i == int(n_epoch*mb_per_epoch):
             
                self.n_log_step += 1 # for logging the results
                
                feed_dict_train = {
                    self.x_data_tf: self.x_train[self.perm_array[:len(self.x_valid)]], 
                    self.y_data_tf: self.y_train[self.perm_array[:len(self.y_valid)]], 
                    self.keep_prob_tf: 1.0}
                
                feed_dict_valid = {self.x_data_tf: self.x_valid, 
                                   self.y_data_tf: self.y_valid, 
                                   self.keep_prob_tf: 1.0}
                
                # summary for tensorboard
                if self.use_tb_summary:
                    train_summary = sess.run(self.merged, feed_dict = feed_dict_train)
                    valid_summary = sess.run(self.merged, feed_dict = feed_dict_valid)
                    self.train_writer.add_summary(train_summary, self.n_log_step)
                    self.valid_writer.add_summary(valid_summary, self.n_log_step)
                
                train_loss.append(sess.run(self.cross_entropy_tf,
                                           feed_dict = feed_dict_train))

                train_acc.append(self.accuracy_tf.eval(session = sess, 
                                                       feed_dict = feed_dict_train))
                
                valid_loss.append(sess.run(self.cross_entropy_tf,
                                           feed_dict = feed_dict_valid))

                valid_acc.append(self.accuracy_tf.eval(session = sess, 
                                                       feed_dict = feed_dict_valid))

                print('%.2f epoch: train/val loss = %.4f/%.4f, train/val acc = %.4f/%.4f'%(
                    self.current_epoch, train_loss[-1], valid_loss[-1],
                    train_acc[-1], valid_acc[-1]))
     
        # concatenate losses and accuracies and assign to tensor variables
        tl_c = np.concatenate([self.train_loss_tf.eval(session=sess), train_loss], axis = 0)
        vl_c = np.concatenate([self.valid_loss_tf.eval(session=sess), valid_loss], axis = 0)
        ta_c = np.concatenate([self.train_acc_tf.eval(session=sess), train_acc], axis = 0)
        va_c = np.concatenate([self.valid_acc_tf.eval(session=sess), valid_acc], axis = 0)
   
        sess.run(tf.assign(self.train_loss_tf, tl_c, validate_shape = False))
        sess.run(tf.assign(self.valid_loss_tf, vl_c , validate_shape = False))
        sess.run(tf.assign(self.train_acc_tf, ta_c , validate_shape = False))
        sess.run(tf.assign(self.valid_acc_tf, va_c , validate_shape = False))
        
        print('running time for training: ', datetime.datetime.now() - start)
        return None
  
    # save tensors/summaries
    def save_model(self, sess):
        
        # tf saver
        if self.use_tf_saver:
            #filepath = os.path.join(os.getcwd(), 'logs' , self.nn_name)
            filepath = os.path.join(os.getcwd(), self.nn_name)
            self.saver_tf.save(sess, filepath)
        
        # tb summary
        if self.use_tb_summary:
            self.train_writer.close()
            self.valid_writer.close()
        
        return None
  
    # forward prediction of current graph
    def forward(self, sess, x_data):
        y_pred_proba = self.y_pred_proba_tf.eval(session = sess, 
                                                 feed_dict = {self.x_data_tf: x_data,
                                                              self.keep_prob_tf: 1.0})
        return y_pred_proba
    
    # function to load tensors from a saved graph
    def load_tensors(self, graph):
        
        # input tensors
        self.x_data_tf = graph.get_tensor_by_name("x_data_tf:0")
        self.y_data_tf = graph.get_tensor_by_name("y_data_tf:0")
        
        # weights and bias tensors
        self.W_conv1_tf = graph.get_tensor_by_name("W_conv1_tf:0")
        self.W_conv2_tf = graph.get_tensor_by_name("W_conv2_tf:0")
        self.W_conv3_tf = graph.get_tensor_by_name("W_conv3_tf:0")
        self.W_fc1_tf = graph.get_tensor_by_name("W_fc1_tf:0")
        self.W_fc2_tf = graph.get_tensor_by_name("W_fc2_tf:0")
        self.b_conv1_tf = graph.get_tensor_by_name("b_conv1_tf:0")
        self.b_conv2_tf = graph.get_tensor_by_name("b_conv2_tf:0")
        self.b_conv3_tf = graph.get_tensor_by_name("b_conv3_tf:0")
        self.b_fc1_tf = graph.get_tensor_by_name("b_fc1_tf:0")
        self.b_fc2_tf = graph.get_tensor_by_name("b_fc2_tf:0")
        
        # activation tensors
        self.h_conv1_tf = graph.get_tensor_by_name('h_conv1_tf:0')  
        self.h_pool1_tf = graph.get_tensor_by_name('h_pool1_tf:0')
        self.h_conv2_tf = graph.get_tensor_by_name('h_conv2_tf:0')
        self.h_pool2_tf = graph.get_tensor_by_name('h_pool2_tf:0')
        self.h_conv3_tf = graph.get_tensor_by_name('h_conv3_tf:0')
        self.h_pool3_tf = graph.get_tensor_by_name('h_pool3_tf:0')
        self.h_fc1_tf = graph.get_tensor_by_name('h_fc1_tf:0')
        self.z_pred_tf = graph.get_tensor_by_name('z_pred_tf:0')
        
        # training and prediction tensors
        self.learn_rate_tf = graph.get_tensor_by_name("learn_rate_tf:0")
        self.keep_prob_tf = graph.get_tensor_by_name("keep_prob_tf:0")
        self.cross_entropy_tf = graph.get_tensor_by_name('cross_entropy_tf:0')
        self.train_step_tf = graph.get_operation_by_name('train_step_tf')
        self.z_pred_tf = graph.get_tensor_by_name('z_pred_tf:0')
        self.y_pred_proba_tf = graph.get_tensor_by_name("y_pred_proba_tf:0")
        self.y_pred_correct_tf = graph.get_tensor_by_name('y_pred_correct_tf:0')
        self.accuracy_tf = graph.get_tensor_by_name('accuracy_tf:0')
        
        # tensor of stored losses and accuricies during training
        self.train_loss_tf = graph.get_tensor_by_name("train_loss_tf:0")
        self.train_acc_tf = graph.get_tensor_by_name("train_acc_tf:0")
        self.valid_loss_tf = graph.get_tensor_by_name("valid_loss_tf:0")
        self.valid_acc_tf = graph.get_tensor_by_name("valid_acc_tf:0")
  
        return None
    
    # get losses of training and validation sets
    def get_loss(self, sess):
        train_loss = self.train_loss_tf.eval(session = sess)
        valid_loss = self.valid_loss_tf.eval(session = sess)
        return train_loss, valid_loss 
        
    # get accuracies of training and validation sets
    def get_accuracy(self, sess):
        train_acc = self.train_acc_tf.eval(session = sess)
        valid_acc = self.valid_acc_tf.eval(session = sess)
        return train_acc, valid_acc 
    
    # get weights
    def get_weights(self, sess):
        W_conv1 = self.W_conv1_tf.eval(session = sess)
        W_conv2 = self.W_conv2_tf.eval(session = sess)
        W_conv3 = self.W_conv3_tf.eval(session = sess)
        W_fc1_tf = self.W_fc1_tf.eval(session = sess)
        W_fc2_tf = self.W_fc2_tf.eval(session = sess)
        return W_conv1, W_conv2, W_conv3, W_fc1_tf, W_fc2_tf
    
    # get biases
    def get_biases(self, sess):
        b_conv1 = self.b_conv1_tf.eval(session = sess)
        b_conv2 = self.b_conv2_tf.eval(session = sess)
        b_conv3 = self.b_conv3_tf.eval(session = sess)
        b_fc1_tf = self.b_fc1_tf.eval(session = sess)
        b_fc2_tf = self.b_fc2_tf.eval(session = sess)
        return b_conv1, b_conv2, b_conv3, b_fc1_tf, b_fc2_tf
    
    # load session from file, restore graph, and load tensors
    def load_session_from_file(self, filename):
        tf.reset_default_graph()
        filepath = os.path.join(os.getcwd(), filename + '.meta')
        #filepath = os.path.join(os.getcwd(),'logs', filename + '.meta')
        saver = tf.train.import_meta_graph(filepath)
        print(filepath)
        sess = tf.Session()
        saver.restore(sess, mn)
        graph = tf.get_default_graph()
        self.load_tensors(graph)
        return sess
    
    # receive activations given the input
    def get_activations(self, sess, x_data):
        feed_dict = {self.x_data_tf: x_data, self.keep_prob_tf: 1.0}
        h_conv1 = self.h_conv1_tf.eval(session = sess, feed_dict = feed_dict)
        h_pool1 = self.h_pool1_tf.eval(session = sess, feed_dict = feed_dict)
        h_conv2 = self.h_conv2_tf.eval(session = sess, feed_dict = feed_dict)
        h_pool2 = self.h_pool2_tf.eval(session = sess, feed_dict = feed_dict)
        h_conv3 = self.h_conv3_tf.eval(session = sess, feed_dict = feed_dict)
        h_pool3 = self.h_pool3_tf.eval(session = sess, feed_dict = feed_dict)
        h_fc1 = self.h_fc1_tf.eval(session = sess, feed_dict = feed_dict)
        h_fc2 = self.z_pred_tf.eval(session = sess, feed_dict = feed_dict)
        return h_conv1,h_pool1,h_conv2,h_pool2,h_conv3,h_pool3,h_fc1,h_fc2

# %% [markdown]
# ## Train and validate the neural network

# %%
## train the neural network graph

nn_name = ['nn0','nn1','nn2','nn3','nn4','nn5','nn6','nn7','nn8','nn9']

# cross validations
cv_num = 10 # cross validations default = 20 => 5% validation set
kfold = sklearn.model_selection.KFold(cv_num, shuffle=True, random_state=123)

for i,(train_index, valid_index) in enumerate(kfold.split(x_train_valid)):
    
    # start timer
    start = datetime.datetime.now();
    
    # train and validation data of original images
    x_train = x_train_valid[train_index]
    y_train = y_train_valid[train_index]
    x_valid = x_train_valid[valid_index]
    y_valid = y_train_valid[valid_index]
    
    # create neural network graph
    nn_graph = nn_class(nn_name = nn_name[i]) # instance of nn_class
    nn_graph.create_graph() # create graph
    nn_graph.attach_saver() # attach saver tensors
    
    # start tensorflow session
    with tf.Session() as sess:
        
        # attach summaries
        nn_graph.attach_summary(sess) 
        
        # variable initialization of the default graph
        sess.run(tf.global_variables_initializer()) 
    
        # training on original data
        nn_graph.train_graph(sess, x_train, y_train, x_valid, y_valid, n_epoch = 1.)
        
        # training on augmented data
        nn_graph.train_graph(sess, x_train, y_train, x_valid, y_valid, n_epoch = 29.,
                             train_on_augmented_data = True)

        # save tensors and summaries of model
        nn_graph.save_model(sess)
    
    break
    
print('total running time for training: ', datetime.datetime.now() - start)
# Out:
# num_weights = 357228
# num_biases = 684
# 28-03-2019 14:55:24 : start training
# learnrate = 0.001 , n_epoch = 1.0 , mb_size = 50 , nn_name = nn0
# 0.01 epoch: train/val loss = 3.7752/3.7194, train/val acc = 0.4883/0.5009
# 0.10 epoch: train/val loss = 0.6351/0.6318, train/val acc = 0.6414/0.6468
# 0.19 epoch: train/val loss = 0.6088/0.5974, train/val acc = 0.6631/0.6811
# 0.28 epoch: train/val loss = 0.5831/0.5691, train/val acc = 0.6865/0.7081
# 0.37 epoch: train/val loss = 0.6554/0.6468, train/val acc = 0.6234/0.6072
# 0.46 epoch: train/val loss = 0.5936/0.5851, train/val acc = 0.6811/0.6811
# 0.55 epoch: train/val loss = 0.5588/0.5474, train/val acc = 0.7261/0.7063
# 0.64 epoch: train/val loss = 0.5856/0.5760, train/val acc = 0.6847/0.6955
# 0.73 epoch: train/val loss = 0.5380/0.5225, train/val acc = 0.7387/0.7784
# 0.82 epoch: train/val loss = 0.5429/0.5275, train/val acc = 0.7441/0.7748
# 0.91 epoch: train/val loss = 0.5185/0.4912, train/val acc = 0.7423/0.7676
# 1.00 epoch: train/val loss = 0.5132/0.4837, train/val acc = 0.7604/0.7910
# running time for training:  0:01:05.478100
# generate new set of images
# generate new set of images
# 28-03-2019 14:56:32 : start training
# learnrate = 0.001 , n_epoch = 29.0 , mb_size = 50 , nn_name = nn0
# 1.01 epoch: train/val loss = 0.5278/0.5106, train/val acc = 0.7748/0.7838
# 1.10 epoch: train/val loss = 0.6059/0.6128, train/val acc = 0.6775/0.6721
# 1.19 epoch: train/val loss = 0.5703/0.5675, train/val acc = 0.7207/0.7045
# 1.28 epoch: train/val loss = 0.5634/0.5543, train/val acc = 0.7333/0.7423
# 1.37 epoch: train/val loss = 0.5451/0.5298, train/val acc = 0.7586/0.7658
# 1.46 epoch: train/val loss = 0.5184/0.4999, train/val acc = 0.7712/0.7910
# 1.55 epoch: train/val loss = 0.5748/0.5330, train/val acc = 0.7099/0.7243
# 1.64 epoch: train/val loss = 0.5607/0.5094, train/val acc = 0.7207/0.7441
# 1.73 epoch: train/val loss = 0.6378/0.5794, train/val acc = 0.6883/0.7081
# 1.82 epoch: train/val loss = 0.5461/0.5131, train/val acc = 0.7153/0.7387
# 1.91 epoch: train/val loss = 0.5193/0.4854, train/val acc = 0.7459/0.7820
# generate new set of images
# 2.00 epoch: train/val loss = 0.5037/0.4768, train/val acc = 0.7405/0.7802
# 2.09 epoch: train/val loss = 0.4840/0.4647, train/val acc = 0.7784/0.7856
# 2.18 epoch: train/val loss = 0.4906/0.4757, train/val acc = 0.7748/0.7982
# 2.27 epoch: train/val loss = 0.4983/0.4860, train/val acc = 0.7640/0.7928
# 2.36 epoch: train/val loss = 0.5860/0.5859, train/val acc = 0.7009/0.7099
# 2.45 epoch: train/val loss = 0.5334/0.5293, train/val acc = 0.7405/0.7477
# 2.54 epoch: train/val loss = 0.5321/0.5291, train/val acc = 0.7495/0.7514
# 2.63 epoch: train/val loss = 0.5130/0.5063, train/val acc = 0.7640/0.7856
# 2.72 epoch: train/val loss = 0.5313/0.4984, train/val acc = 0.7351/0.7532
# 2.81 epoch: train/val loss = 0.5195/0.4959, train/val acc = 0.7369/0.7586
# 2.90 epoch: train/val loss = 0.5294/0.5048, train/val acc = 0.7387/0.7514
# generate new set of images
# 2.99 epoch: train/val loss = 0.5504/0.5185, train/val acc = 0.7351/0.7297
# 0:02:18.173040 : set learn rate to 0.000750
# 3.08 epoch: train/val loss = 0.5464/0.5294, train/val acc = 0.7369/0.7423
# 3.18 epoch: train/val loss = 0.4988/0.4804, train/val acc = 0.7766/0.8000
# 3.27 epoch: train/val loss = 0.4985/0.4747, train/val acc = 0.7622/0.7928
# 3.36 epoch: train/val loss = 0.4913/0.4640, train/val acc = 0.7712/0.7964
# 3.45 epoch: train/val loss = 0.4898/0.4587, train/val acc = 0.7712/0.7928
# 3.54 epoch: train/val loss = 0.5308/0.4947, train/val acc = 0.7459/0.7604
# 3.63 epoch: train/val loss = 0.4994/0.4736, train/val acc = 0.7676/0.7784
# 3.72 epoch: train/val loss = 0.5108/0.4964, train/val acc = 0.7766/0.8018
# 3.81 epoch: train/val loss = 0.4949/0.4798, train/val acc = 0.7784/0.7982
# 3.90 epoch: train/val loss = 0.4887/0.4719, train/val acc = 0.7820/0.7874
# generate new set of images
# 3.99 epoch: train/val loss = 0.5205/0.4676, train/val acc = 0.7369/0.7928
# 4.08 epoch: train/val loss = 0.5215/0.4792, train/val acc = 0.7423/0.7982
# 4.17 epoch: train/val loss = 0.5127/0.4698, train/val acc = 0.7459/0.7856
# 4.26 epoch: train/val loss = 0.5070/0.4613, train/val acc = 0.7550/0.7928
# 4.35 epoch: train/val loss = 0.5080/0.4607, train/val acc = 0.7459/0.7928
# 4.44 epoch: train/val loss = 0.5125/0.4570, train/val acc = 0.7514/0.8000
# 4.53 epoch: train/val loss = 0.5095/0.4599, train/val acc = 0.7550/0.7910
# 4.62 epoch: train/val loss = 0.5055/0.4616, train/val acc = 0.7459/0.8018
# 4.71 epoch: train/val loss = 0.5243/0.4760, train/val acc = 0.7495/0.7748
# 4.80 epoch: train/val loss = 0.5621/0.5043, train/val acc = 0.7225/0.7748
# 4.89 epoch: train/val loss = 0.5524/0.4992, train/val acc = 0.7297/0.8000
# generate new set of images
# 4.98 epoch: train/val loss = 0.5347/0.5057, train/val acc = 0.7297/0.7459
# 5.07 epoch: train/val loss = 0.4853/0.4793, train/val acc = 0.7676/0.7946
# 5.16 epoch: train/val loss = 0.4915/0.5066, train/val acc = 0.7622/0.7784
# 5.25 epoch: train/val loss = 0.5460/0.5133, train/val acc = 0.7279/0.7387
# 5.34 epoch: train/val loss = 0.5093/0.5187, train/val acc = 0.7604/0.7604
# 5.43 epoch: train/val loss = 0.4871/0.4689, train/val acc = 0.7748/0.7982
# 5.52 epoch: train/val loss = 0.4860/0.4659, train/val acc = 0.7802/0.7964
# 5.61 epoch: train/val loss = 0.4738/0.4585, train/val acc = 0.7748/0.8018
# 5.70 epoch: train/val loss = 0.4853/0.4541, train/val acc = 0.7730/0.7964
# 5.79 epoch: train/val loss = 0.5046/0.4692, train/val acc = 0.7568/0.7802
# 5.88 epoch: train/val loss = 0.4724/0.4572, train/val acc = 0.7658/0.7982
# generate new set of images
# 5.97 epoch: train/val loss = 0.4691/0.4750, train/val acc = 0.8036/0.7982
# 0:05:55.992280 : set learn rate to 0.000500
# 6.06 epoch: train/val loss = 0.4597/0.4675, train/val acc = 0.7928/0.7910
# 6.15 epoch: train/val loss = 0.4514/0.4656, train/val acc = 0.8036/0.7964
# 6.24 epoch: train/val loss = 0.4658/0.4587, train/val acc = 0.7766/0.7874
# 6.33 epoch: train/val loss = 0.4536/0.4631, train/val acc = 0.7964/0.8090
# 6.42 epoch: train/val loss = 0.4770/0.4987, train/val acc = 0.7964/0.7856
# 6.51 epoch: train/val loss = 0.4627/0.4701, train/val acc = 0.7964/0.8072
# 6.60 epoch: train/val loss = 0.4651/0.4586, train/val acc = 0.7892/0.8036
# 6.69 epoch: train/val loss = 0.4578/0.4570, train/val acc = 0.7928/0.8126
# 6.78 epoch: train/val loss = 0.4956/0.5145, train/val acc = 0.7748/0.7477
# 6.87 epoch: train/val loss = 0.5166/0.4995, train/val acc = 0.7441/0.7586
# generate new set of images
# 6.96 epoch: train/val loss = 0.5153/0.4976, train/val acc = 0.7568/0.7694
# 7.05 epoch: train/val loss = 0.4967/0.4616, train/val acc = 0.7640/0.7946
# 7.14 epoch: train/val loss = 0.4871/0.4565, train/val acc = 0.7604/0.8018
# 7.23 epoch: train/val loss = 0.4928/0.4534, train/val acc = 0.7622/0.7964
# 7.32 epoch: train/val loss = 0.5082/0.4880, train/val acc = 0.7477/0.7784
# 7.41 epoch: train/val loss = 0.4877/0.4564, train/val acc = 0.7658/0.8072
# 7.50 epoch: train/val loss = 0.4937/0.4563, train/val acc = 0.7640/0.7892
# 7.59 epoch: train/val loss = 0.5232/0.4929, train/val acc = 0.7604/0.7892
# 7.68 epoch: train/val loss = 0.5015/0.4671, train/val acc = 0.7658/0.8036
# 7.77 epoch: train/val loss = 0.4873/0.4538, train/val acc = 0.7550/0.8036
# 7.86 epoch: train/val loss = 0.4970/0.4532, train/val acc = 0.7441/0.7892
# generate new set of images
# 7.95 epoch: train/val loss = 0.4611/0.4518, train/val acc = 0.7874/0.8000
# 8.04 epoch: train/val loss = 0.4708/0.4676, train/val acc = 0.7892/0.7946
# 8.13 epoch: train/val loss = 0.4580/0.4513, train/val acc = 0.7964/0.8000
# 8.22 epoch: train/val loss = 0.4602/0.4491, train/val acc = 0.7748/0.7874
# 8.31 epoch: train/val loss = 0.5084/0.5103, train/val acc = 0.7586/0.7640
# 8.40 epoch: train/val loss = 0.4639/0.4513, train/val acc = 0.7874/0.8036
# 8.49 epoch: train/val loss = 0.4739/0.4780, train/val acc = 0.7856/0.7892
# 8.58 epoch: train/val loss = 0.4575/0.4548, train/val acc = 0.7856/0.8054
# 8.67 epoch: train/val loss = 0.4642/0.4504, train/val acc = 0.7946/0.8072
# 8.76 epoch: train/val loss = 0.4635/0.4575, train/val acc = 0.7964/0.8018
# 8.85 epoch: train/val loss = 0.5126/0.5189, train/val acc = 0.7369/0.7514
# generate new set of images
# 8.94 epoch: train/val loss = 0.5004/0.4584, train/val acc = 0.7766/0.7928
# 0:09:32.350401 : set learn rate to 0.000250
# 9.03 epoch: train/val loss = 0.4881/0.4658, train/val acc = 0.7640/0.7982
# 9.12 epoch: train/val loss = 0.4799/0.4529, train/val acc = 0.7748/0.8108
# 9.21 epoch: train/val loss = 0.4806/0.4553, train/val acc = 0.7676/0.8072
# 9.30 epoch: train/val loss = 0.4816/0.4580, train/val acc = 0.7676/0.7946
# 9.40 epoch: train/val loss = 0.4821/0.4484, train/val acc = 0.7748/0.8036
# 9.49 epoch: train/val loss = 0.5308/0.5228, train/val acc = 0.7387/0.7459
# 9.58 epoch: train/val loss = 0.4840/0.4505, train/val acc = 0.7856/0.8054
# 9.67 epoch: train/val loss = 0.4863/0.4659, train/val acc = 0.7694/0.7982
# 9.76 epoch: train/val loss = 0.4843/0.4616, train/val acc = 0.7694/0.8018
# 9.85 epoch: train/val loss = 0.4802/0.4530, train/val acc = 0.7676/0.8036
# generate new set of images
# 9.94 epoch: train/val loss = 0.4866/0.4476, train/val acc = 0.7748/0.7964
# 10.03 epoch: train/val loss = 0.4874/0.4586, train/val acc = 0.7676/0.8000
# 10.12 epoch: train/val loss = 0.4862/0.4584, train/val acc = 0.7694/0.7982
# 10.21 epoch: train/val loss = 0.4808/0.4482, train/val acc = 0.7802/0.8054
# 10.30 epoch: train/val loss = 0.4831/0.4455, train/val acc = 0.7784/0.8090
# 10.39 epoch: train/val loss = 0.4852/0.4543, train/val acc = 0.7748/0.7964
# 10.48 epoch: train/val loss = 0.5043/0.4830, train/val acc = 0.7604/0.7838
# 10.57 epoch: train/val loss = 0.4856/0.4440, train/val acc = 0.7766/0.8000
# 10.66 epoch: train/val loss = 0.4943/0.4661, train/val acc = 0.7550/0.7982
# 10.75 epoch: train/val loss = 0.4847/0.4460, train/val acc = 0.7748/0.7982
# 10.84 epoch: train/val loss = 0.4964/0.4712, train/val acc = 0.7694/0.7964
# generate new set of images
# 10.93 epoch: train/val loss = 0.4944/0.4480, train/val acc = 0.7550/0.7982
# 11.02 epoch: train/val loss = 0.5499/0.5354, train/val acc = 0.7135/0.7351
# 11.11 epoch: train/val loss = 0.5211/0.4731, train/val acc = 0.7532/0.7802
# 11.20 epoch: train/val loss = 0.5100/0.4902, train/val acc = 0.7441/0.7748
# 11.29 epoch: train/val loss = 0.4870/0.4500, train/val acc = 0.7568/0.8072
# 11.38 epoch: train/val loss = 0.5141/0.4896, train/val acc = 0.7423/0.7802
# 11.47 epoch: train/val loss = 0.5039/0.4551, train/val acc = 0.7604/0.7964
# 11.56 epoch: train/val loss = 0.5108/0.4873, train/val acc = 0.7333/0.7838
# 11.65 epoch: train/val loss = 0.4944/0.4516, train/val acc = 0.7495/0.7874
# 11.74 epoch: train/val loss = 0.4881/0.4564, train/val acc = 0.7568/0.8018
# 11.83 epoch: train/val loss = 0.4851/0.4520, train/val acc = 0.7586/0.8054
# generate new set of images
# 11.92 epoch: train/val loss = 0.4765/0.4576, train/val acc = 0.7766/0.7910
# 12.01 epoch: train/val loss = 0.4755/0.4517, train/val acc = 0.7802/0.7910
# 0:13:16.236919 : set learn rate to 0.000100
# 12.10 epoch: train/val loss = 0.4815/0.4474, train/val acc = 0.7802/0.8036
# 12.19 epoch: train/val loss = 0.4733/0.4555, train/val acc = 0.7784/0.7856
# 12.28 epoch: train/val loss = 0.4746/0.4623, train/val acc = 0.7784/0.7802
# 12.37 epoch: train/val loss = 0.4780/0.4453, train/val acc = 0.7802/0.7946
# 12.46 epoch: train/val loss = 0.4761/0.4603, train/val acc = 0.7802/0.7874
# 12.55 epoch: train/val loss = 0.4749/0.4532, train/val acc = 0.7748/0.7928
# 12.64 epoch: train/val loss = 0.4876/0.4441, train/val acc = 0.7730/0.8000
# 12.73 epoch: train/val loss = 0.4791/0.4428, train/val acc = 0.7766/0.7946
# 12.82 epoch: train/val loss = 0.4782/0.4633, train/val acc = 0.7820/0.7928
# generate new set of images
# 12.91 epoch: train/val loss = 0.4598/0.4443, train/val acc = 0.7910/0.8018
# 13.00 epoch: train/val loss = 0.4571/0.4515, train/val acc = 0.7946/0.8018
# 13.09 epoch: train/val loss = 0.4580/0.4593, train/val acc = 0.7892/0.7964
# 13.18 epoch: train/val loss = 0.4559/0.4464, train/val acc = 0.7946/0.8054
# 13.27 epoch: train/val loss = 0.4650/0.4431, train/val acc = 0.7946/0.8018
# 13.36 epoch: train/val loss = 0.4578/0.4591, train/val acc = 0.7892/0.8000
# 13.45 epoch: train/val loss = 0.4582/0.4444, train/val acc = 0.7910/0.8036
# 13.54 epoch: train/val loss = 0.4595/0.4581, train/val acc = 0.7874/0.7982
# 13.63 epoch: train/val loss = 0.4586/0.4464, train/val acc = 0.7892/0.8000
# 13.72 epoch: train/val loss = 0.4588/0.4453, train/val acc = 0.7856/0.8072
# 13.81 epoch: train/val loss = 0.4590/0.4438, train/val acc = 0.7892/0.8018
# generate new set of images
# 13.90 epoch: train/val loss = 0.4574/0.4436, train/val acc = 0.7730/0.8000
# 13.99 epoch: train/val loss = 0.4558/0.4493, train/val acc = 0.7676/0.7946
# 14.08 epoch: train/val loss = 0.4621/0.4456, train/val acc = 0.7748/0.7964
# 14.17 epoch: train/val loss = 0.4573/0.4544, train/val acc = 0.7748/0.7982
# 14.26 epoch: train/val loss = 0.4573/0.4515, train/val acc = 0.7694/0.8000
# 14.35 epoch: train/val loss = 0.4592/0.4507, train/val acc = 0.7676/0.8018
# 14.44 epoch: train/val loss = 0.4600/0.4426, train/val acc = 0.7712/0.7964
# 14.53 epoch: train/val loss = 0.4642/0.4419, train/val acc = 0.7766/0.7946
# 14.62 epoch: train/val loss = 0.4720/0.4719, train/val acc = 0.7748/0.7910
# 14.71 epoch: train/val loss = 0.4622/0.4559, train/val acc = 0.7694/0.8000
# 14.80 epoch: train/val loss = 0.4598/0.4488, train/val acc = 0.7658/0.8036
# generate new set of images
# 14.89 epoch: train/val loss = 0.4366/0.4597, train/val acc = 0.8126/0.8018
# 14.98 epoch: train/val loss = 0.4276/0.4444, train/val acc = 0.8090/0.8018
# 0:16:56.574532 : set learn rate to 0.000100
# 15.07 epoch: train/val loss = 0.4285/0.4501, train/val acc = 0.8090/0.8018
# 15.16 epoch: train/val loss = 0.4325/0.4562, train/val acc = 0.8090/0.8054
# 15.25 epoch: train/val loss = 0.4304/0.4498, train/val acc = 0.8126/0.8054
# 15.34 epoch: train/val loss = 0.4286/0.4444, train/val acc = 0.8090/0.7964
# 15.43 epoch: train/val loss = 0.4304/0.4419, train/val acc = 0.7910/0.7910
# 15.52 epoch: train/val loss = 0.4266/0.4445, train/val acc = 0.8126/0.8036
# 15.61 epoch: train/val loss = 0.4251/0.4431, train/val acc = 0.8090/0.8018
# 15.71 epoch: train/val loss = 0.4358/0.4620, train/val acc = 0.8126/0.7946
# 15.80 epoch: train/val loss = 0.4340/0.4579, train/val acc = 0.8090/0.8036
# generate new set of images
# 15.89 epoch: train/val loss = 0.4508/0.4475, train/val acc = 0.7838/0.8000
# 15.98 epoch: train/val loss = 0.4473/0.4461, train/val acc = 0.7928/0.7946
# 16.07 epoch: train/val loss = 0.4463/0.4432, train/val acc = 0.7874/0.8018
# 16.16 epoch: train/val loss = 0.4468/0.4410, train/val acc = 0.7820/0.8018
# 16.25 epoch: train/val loss = 0.4592/0.4589, train/val acc = 0.7856/0.8018
# 16.34 epoch: train/val loss = 0.4699/0.4695, train/val acc = 0.7838/0.7820
# 16.43 epoch: train/val loss = 0.4576/0.4423, train/val acc = 0.7856/0.7964
# 16.52 epoch: train/val loss = 0.4567/0.4476, train/val acc = 0.7874/0.8054
# 16.61 epoch: train/val loss = 0.4526/0.4458, train/val acc = 0.7856/0.8000
# 16.70 epoch: train/val loss = 0.4519/0.4435, train/val acc = 0.7856/0.8000
# 16.79 epoch: train/val loss = 0.4624/0.4636, train/val acc = 0.7928/0.7964
# generate new set of images
# 16.88 epoch: train/val loss = 0.4620/0.4481, train/val acc = 0.8000/0.7982
# 16.97 epoch: train/val loss = 0.4590/0.4439, train/val acc = 0.7910/0.7964
# 17.06 epoch: train/val loss = 0.4784/0.4794, train/val acc = 0.7928/0.7802
# 17.15 epoch: train/val loss = 0.4587/0.4491, train/val acc = 0.7946/0.7982
# 17.24 epoch: train/val loss = 0.4577/0.4435, train/val acc = 0.7892/0.7928
# 17.33 epoch: train/val loss = 0.4716/0.4704, train/val acc = 0.7874/0.7892
# 17.42 epoch: train/val loss = 0.4671/0.4448, train/val acc = 0.7802/0.7964
# 17.51 epoch: train/val loss = 0.4563/0.4436, train/val acc = 0.7964/0.7982
# 17.60 epoch: train/val loss = 0.4846/0.4876, train/val acc = 0.7748/0.7694
# 17.69 epoch: train/val loss = 0.4680/0.4458, train/val acc = 0.7784/0.8018
# 17.78 epoch: train/val loss = 0.4610/0.4456, train/val acc = 0.7964/0.8000
# generate new set of images
# 17.87 epoch: train/val loss = 0.4407/0.4500, train/val acc = 0.8054/0.8018
# 17.96 epoch: train/val loss = 0.4396/0.4622, train/val acc = 0.8108/0.8000
# 0:20:34.168446 : set learn rate to 0.000100
# 18.05 epoch: train/val loss = 0.4401/0.4451, train/val acc = 0.7928/0.8018
# 18.14 epoch: train/val loss = 0.4421/0.4436, train/val acc = 0.7874/0.7910
# 18.23 epoch: train/val loss = 0.4355/0.4584, train/val acc = 0.8144/0.8036
# 18.32 epoch: train/val loss = 0.4394/0.4440, train/val acc = 0.7946/0.7964
# 18.41 epoch: train/val loss = 0.4359/0.4478, train/val acc = 0.8072/0.8054
# 18.50 epoch: train/val loss = 0.4356/0.4509, train/val acc = 0.8054/0.8018
# 18.59 epoch: train/val loss = 0.4385/0.4435, train/val acc = 0.7982/0.8000
# 18.68 epoch: train/val loss = 0.4383/0.4430, train/val acc = 0.7946/0.7982
# 18.77 epoch: train/val loss = 0.4364/0.4535, train/val acc = 0.8054/0.7982
# generate new set of images
# 18.86 epoch: train/val loss = 0.4650/0.4442, train/val acc = 0.7874/0.7982
# 18.95 epoch: train/val loss = 0.4646/0.4529, train/val acc = 0.7892/0.7910
# 19.04 epoch: train/val loss = 0.4616/0.4464, train/val acc = 0.7874/0.7928
# 19.13 epoch: train/val loss = 0.4633/0.4522, train/val acc = 0.7874/0.8000
# 19.22 epoch: train/val loss = 0.4649/0.4555, train/val acc = 0.7838/0.7982
# 19.31 epoch: train/val loss = 0.4626/0.4478, train/val acc = 0.7910/0.8000
# 19.40 epoch: train/val loss = 0.4802/0.4744, train/val acc = 0.7694/0.7838
# 19.49 epoch: train/val loss = 0.4624/0.4455, train/val acc = 0.7892/0.7982
# 19.58 epoch: train/val loss = 0.4744/0.4646, train/val acc = 0.7694/0.7820
# 19.67 epoch: train/val loss = 0.4711/0.4451, train/val acc = 0.7928/0.8000
# 19.76 epoch: train/val loss = 0.4730/0.4487, train/val acc = 0.7856/0.7982
# generate new set of images
# 19.85 epoch: train/val loss = 0.4739/0.4499, train/val acc = 0.7784/0.7964
# 19.94 epoch: train/val loss = 0.4503/0.4531, train/val acc = 0.8054/0.8000
# 20.03 epoch: train/val loss = 0.4494/0.4508, train/val acc = 0.8036/0.7982
# 20.12 epoch: train/val loss = 0.4499/0.4470, train/val acc = 0.7982/0.7964
# 20.21 epoch: train/val loss = 0.4499/0.4476, train/val acc = 0.8018/0.7964
# 20.30 epoch: train/val loss = 0.4553/0.4592, train/val acc = 0.7874/0.7964
# 20.39 epoch: train/val loss = 0.4501/0.4433, train/val acc = 0.7910/0.7892
# 20.48 epoch: train/val loss = 0.4512/0.4412, train/val acc = 0.7874/0.7892
# 20.57 epoch: train/val loss = 0.4659/0.4747, train/val acc = 0.7766/0.7802
# 20.66 epoch: train/val loss = 0.4522/0.4459, train/val acc = 0.7964/0.7964
# 20.75 epoch: train/val loss = 0.4563/0.4504, train/val acc = 0.7910/0.7946
# generate new set of images
# 20.84 epoch: train/val loss = 0.4511/0.4405, train/val acc = 0.7928/0.8036
# 20.93 epoch: train/val loss = 0.4516/0.4456, train/val acc = 0.7946/0.7982
# 0:24:16.027721 : set learn rate to 0.000075
# 21.02 epoch: train/val loss = 0.4650/0.4618, train/val acc = 0.7856/0.7946
# 21.11 epoch: train/val loss = 0.4548/0.4404, train/val acc = 0.7892/0.7964
# 21.20 epoch: train/val loss = 0.4574/0.4449, train/val acc = 0.7910/0.8000
# 21.29 epoch: train/val loss = 0.4580/0.4462, train/val acc = 0.7910/0.7982
# 21.38 epoch: train/val loss = 0.4600/0.4523, train/val acc = 0.7874/0.8000
# 21.47 epoch: train/val loss = 0.4633/0.4604, train/val acc = 0.7820/0.7982
# 21.56 epoch: train/val loss = 0.4514/0.4456, train/val acc = 0.7910/0.7946
# 21.65 epoch: train/val loss = 0.4504/0.4430, train/val acc = 0.7910/0.7982
# 21.74 epoch: train/val loss = 0.4510/0.4405, train/val acc = 0.7928/0.8036
# generate new set of images
# 21.83 epoch: train/val loss = 0.4391/0.4485, train/val acc = 0.8072/0.7982
# 21.93 epoch: train/val loss = 0.4376/0.4480, train/val acc = 0.8072/0.7964
# 22.02 epoch: train/val loss = 0.4431/0.4642, train/val acc = 0.8090/0.7928
# 22.11 epoch: train/val loss = 0.4364/0.4402, train/val acc = 0.8054/0.7946
# 22.20 epoch: train/val loss = 0.4395/0.4390, train/val acc = 0.8036/0.8000
# 22.29 epoch: train/val loss = 0.4373/0.4439, train/val acc = 0.8072/0.7982
# 22.38 epoch: train/val loss = 0.4366/0.4425, train/val acc = 0.8054/0.7982
# 22.47 epoch: train/val loss = 0.4380/0.4413, train/val acc = 0.8108/0.7946
# 22.56 epoch: train/val loss = 0.4379/0.4425, train/val acc = 0.8072/0.7910
# 22.65 epoch: train/val loss = 0.4416/0.4549, train/val acc = 0.8108/0.7982
# 22.74 epoch: train/val loss = 0.4377/0.4449, train/val acc = 0.8018/0.7964
# generate new set of images
# 22.83 epoch: train/val loss = 0.4512/0.4440, train/val acc = 0.7874/0.7946
# 22.92 epoch: train/val loss = 0.4500/0.4462, train/val acc = 0.7910/0.7946
# 23.01 epoch: train/val loss = 0.4535/0.4545, train/val acc = 0.7856/0.7964
# 23.10 epoch: train/val loss = 0.4507/0.4430, train/val acc = 0.7946/0.7946
# 23.19 epoch: train/val loss = 0.4526/0.4403, train/val acc = 0.7802/0.7928
# 23.28 epoch: train/val loss = 0.4532/0.4419, train/val acc = 0.7820/0.7928
# 23.37 epoch: train/val loss = 0.4660/0.4673, train/val acc = 0.7784/0.7964
# 23.46 epoch: train/val loss = 0.4513/0.4429, train/val acc = 0.7874/0.7946
# 23.55 epoch: train/val loss = 0.4499/0.4458, train/val acc = 0.7946/0.7910
# 23.64 epoch: train/val loss = 0.4495/0.4420, train/val acc = 0.7838/0.7892
# 23.73 epoch: train/val loss = 0.4558/0.4396, train/val acc = 0.7748/0.7964
# generate new set of images
# 23.82 epoch: train/val loss = 0.4741/0.4638, train/val acc = 0.7766/0.7892
# 23.91 epoch: train/val loss = 0.4623/0.4436, train/val acc = 0.7856/0.7910
# 24.00 epoch: train/val loss = 0.4648/0.4424, train/val acc = 0.7802/0.7874
# 0:28:01.388015 : set learn rate to 0.000050
# 24.09 epoch: train/val loss = 0.4616/0.4495, train/val acc = 0.7928/0.8000
# 24.18 epoch: train/val loss = 0.4632/0.4480, train/val acc = 0.7964/0.7964
# 24.27 epoch: train/val loss = 0.4659/0.4425, train/val acc = 0.7856/0.7892
# 24.36 epoch: train/val loss = 0.4696/0.4530, train/val acc = 0.7946/0.7964
# 24.45 epoch: train/val loss = 0.4666/0.4468, train/val acc = 0.7910/0.7910
# 24.54 epoch: train/val loss = 0.4666/0.4408, train/val acc = 0.7820/0.7892
# 24.63 epoch: train/val loss = 0.4708/0.4574, train/val acc = 0.7820/0.8000
# 24.72 epoch: train/val loss = 0.4809/0.4731, train/val acc = 0.7766/0.7856
# generate new set of images
# 24.81 epoch: train/val loss = 0.4549/0.4395, train/val acc = 0.7964/0.7964
# 24.90 epoch: train/val loss = 0.4514/0.4437, train/val acc = 0.8018/0.7946
# 24.99 epoch: train/val loss = 0.4512/0.4478, train/val acc = 0.8018/0.7946
# 25.08 epoch: train/val loss = 0.4527/0.4399, train/val acc = 0.7964/0.7964
# 25.17 epoch: train/val loss = 0.4509/0.4456, train/val acc = 0.8000/0.7928
# 25.26 epoch: train/val loss = 0.4508/0.4458, train/val acc = 0.7982/0.7910
# 25.35 epoch: train/val loss = 0.4511/0.4437, train/val acc = 0.8018/0.7946
# 25.44 epoch: train/val loss = 0.4520/0.4465, train/val acc = 0.8000/0.7964
# 25.53 epoch: train/val loss = 0.4517/0.4456, train/val acc = 0.7982/0.7964
# 25.62 epoch: train/val loss = 0.4525/0.4399, train/val acc = 0.8054/0.7964
# 25.71 epoch: train/val loss = 0.4521/0.4406, train/val acc = 0.8018/0.7946
# generate new set of images
# 25.80 epoch: train/val loss = 0.4438/0.4507, train/val acc = 0.8108/0.7982
# 25.89 epoch: train/val loss = 0.4430/0.4501, train/val acc = 0.8108/0.8000
# 25.98 epoch: train/val loss = 0.4412/0.4462, train/val acc = 0.8108/0.7982
# 26.07 epoch: train/val loss = 0.4406/0.4416, train/val acc = 0.7928/0.7946
# 26.16 epoch: train/val loss = 0.4404/0.4428, train/val acc = 0.8000/0.7964
# 26.25 epoch: train/val loss = 0.4409/0.4466, train/val acc = 0.8108/0.7928
# 26.34 epoch: train/val loss = 0.4408/0.4423, train/val acc = 0.7982/0.7964
# 26.43 epoch: train/val loss = 0.4444/0.4383, train/val acc = 0.7964/0.7910
# 26.52 epoch: train/val loss = 0.4440/0.4470, train/val acc = 0.8000/0.8000
# 26.61 epoch: train/val loss = 0.4446/0.4406, train/val acc = 0.8018/0.7946
# 26.70 epoch: train/val loss = 0.4460/0.4553, train/val acc = 0.8090/0.8036
# generate new set of images
# 26.79 epoch: train/val loss = 0.4847/0.4617, train/val acc = 0.7604/0.7982
# 26.88 epoch: train/val loss = 0.4747/0.4395, train/val acc = 0.7802/0.7910
# 26.97 epoch: train/val loss = 0.4758/0.4487, train/val acc = 0.7730/0.7946
# 0:31:43.736779 : set learn rate to 0.000025
# 27.06 epoch: train/val loss = 0.4753/0.4480, train/val acc = 0.7730/0.7982
# 27.15 epoch: train/val loss = 0.4738/0.4422, train/val acc = 0.7802/0.7964
# 27.24 epoch: train/val loss = 0.4745/0.4453, train/val acc = 0.7766/0.8000
# 27.33 epoch: train/val loss = 0.4770/0.4516, train/val acc = 0.7712/0.7982
# 27.42 epoch: train/val loss = 0.4736/0.4433, train/val acc = 0.7820/0.7946
# 27.51 epoch: train/val loss = 0.4738/0.4409, train/val acc = 0.7856/0.7946
# 27.60 epoch: train/val loss = 0.4740/0.4402, train/val acc = 0.7856/0.7928
# 27.69 epoch: train/val loss = 0.4766/0.4489, train/val acc = 0.7730/0.7982
# generate new set of images
# 27.78 epoch: train/val loss = 0.4332/0.4473, train/val acc = 0.8072/0.7964
# 27.87 epoch: train/val loss = 0.4330/0.4474, train/val acc = 0.8072/0.7964
# 27.96 epoch: train/val loss = 0.4305/0.4427, train/val acc = 0.7964/0.7982
# 28.05 epoch: train/val loss = 0.4302/0.4429, train/val acc = 0.7964/0.7964
# 28.15 epoch: train/val loss = 0.4295/0.4397, train/val acc = 0.7910/0.7946
# 28.24 epoch: train/val loss = 0.4299/0.4433, train/val acc = 0.7946/0.7964
# 28.33 epoch: train/val loss = 0.4314/0.4463, train/val acc = 0.8036/0.7946
# 28.42 epoch: train/val loss = 0.4299/0.4420, train/val acc = 0.7964/0.7964
# 28.51 epoch: train/val loss = 0.4311/0.4446, train/val acc = 0.8036/0.7928
# 28.60 epoch: train/val loss = 0.4301/0.4421, train/val acc = 0.8000/0.7946
# 28.69 epoch: train/val loss = 0.4316/0.4449, train/val acc = 0.8054/0.7928
# generate new set of images
# 28.78 epoch: train/val loss = 0.4668/0.4481, train/val acc = 0.7946/0.7982
# 28.87 epoch: train/val loss = 0.4638/0.4432, train/val acc = 0.7874/0.7964
# 28.96 epoch: train/val loss = 0.4622/0.4399, train/val acc = 0.7982/0.7946
# 29.05 epoch: train/val loss = 0.4621/0.4405, train/val acc = 0.7928/0.7928
# 29.14 epoch: train/val loss = 0.4631/0.4432, train/val acc = 0.7874/0.7982
# 29.23 epoch: train/val loss = 0.4660/0.4483, train/val acc = 0.7910/0.8000
# 29.32 epoch: train/val loss = 0.4641/0.4451, train/val acc = 0.7892/0.7910
# 29.41 epoch: train/val loss = 0.4678/0.4511, train/val acc = 0.7928/0.8000
# 29.50 epoch: train/val loss = 0.4683/0.4517, train/val acc = 0.7928/0.8018
# 29.59 epoch: train/val loss = 0.4627/0.4415, train/val acc = 0.7910/0.7946
# 29.68 epoch: train/val loss = 0.4624/0.4379, train/val acc = 0.8000/0.7910
# generate new set of images
# 29.77 epoch: train/val loss = 0.4534/0.4406, train/val acc = 0.7802/0.7946
# 29.86 epoch: train/val loss = 0.4526/0.4502, train/val acc = 0.7928/0.8018
# 29.95 epoch: train/val loss = 0.4536/0.4537, train/val acc = 0.7910/0.8018
# 30.01 epoch: train/val loss = 0.4521/0.4473, train/val acc = 0.7910/0.7964
# running time for training:  0:35:28.436450
# total running time for training:  0:36:39.229643

# %%
## visualization with tensorboard
if False:
    # !tensorboard --logdir=./logs

# %%
## loss and accuracy curves

# choose neural network
mn = nn_name[0]
nn_graph = nn_class()
sess = nn_graph.load_session_from_file(mn)
train_loss[mn], valid_loss[mn] = nn_graph.get_loss(sess)
train_acc[mn], valid_acc[mn] = nn_graph.get_accuracy(sess)
sess.close()

print('final train/valid loss = %.4f/%.4f, train/valid accuracy = %.4f/%.4f'%(
    train_loss[mn][-1], valid_loss[mn][-1], train_acc[mn][-1], valid_acc[mn][-1]))

plt.figure(figsize=(10, 5));
plt.subplot(1,2,1);
plt.plot(np.arange(0,len(train_acc[mn])), train_acc[mn],'-b', label='Training')
plt.plot(np.arange(0,len(valid_acc[mn])), valid_acc[mn],'-g', label='Validation')
plt.legend(loc='lower right', frameon=False)
plt.ylim(ymax = 1.1, ymin = 0.0)
plt.ylabel('accuracy')
plt.xlabel('log steps');

plt.subplot(1,2,2)
plt.plot(np.arange(0,len(train_loss[mn])), train_loss[mn],'-b', label='Training')
plt.plot(np.arange(0,len(valid_loss[mn])), valid_loss[mn],'-g', label='Validation')
plt.legend(loc='lower right', frameon=False)
plt.ylim(ymax = 3.0, ymin = 0.0)
plt.ylabel('loss')
plt.xlabel('log steps');
# Out:
# C:\Users\missd\tensorflow\Final Project\Cancer image\nn0.meta
# INFO:tensorflow:Restoring parameters from nn0
# final train/valid loss = 0.4521/0.4473, train/valid accuracy = 0.7910/0.7964

# %%
## show confusion matrix

# choose neural network
mn = nn_name[0]
nn_graph = nn_class()
sess = nn_graph.load_session_from_file(mn)
y_valid_pred[mn] = nn_graph.forward(sess, x_valid)
sess.close()

# confusion matrix
cnf_valid_matrix['neural_network'] = sklearn.metrics.confusion_matrix(
    y_pred = one_hot_to_dense(y_valid_pred[mn]), 
    y_true = one_hot_to_dense(y_valid)).astype(np.float32)

# normalize
cnf_valid_matrix['neural_network'][0,:] = cnf_valid_matrix['neural_network'][0,:]/cnf_valid_matrix['neural_network'][0,:].sum()  
cnf_valid_matrix['neural_network'][1,:] = cnf_valid_matrix['neural_network'][1,:]/cnf_valid_matrix['neural_network'][1,:].sum()  

# plot
labels_array = ['IDC = 0', 'IDC = 1']
fig, ax = plt.subplots(1,figsize=(5,5))
ax = sns.heatmap(cnf_valid_matrix['neural_network'], ax=ax, cmap=plt.cm.Greens, annot=True)
ax.set_xticklabels(labels_array)
ax.set_yticklabels(labels_array)
plt.title('Confusion matrix of validation set')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show();
# Out:
# C:\Users\missd\tensorflow\Final Project\Cancer image\nn0.meta
# INFO:tensorflow:Restoring parameters from nn0
